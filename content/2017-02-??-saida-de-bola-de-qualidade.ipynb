# %%
import glob
import os.path

import pandas as pd

key_entries_files = glob.glob(os.path.join('data', 'StrataData_keyEntries_*.csv'))
key_entries = pd.concat([pd.read_csv(f, index_col=0, na_values='-') for f in key_entries_files])

# %%
key_entries
# Out:
#      competition     gsm_id kickoffDate kickoffTime     hometeam_team1  \
# 671        EngPr  2241996.0  2017-02-04    17:30:00  Tottenham Hotspur
# 672        EngPr  2241996.0  2017-02-04    17:30:00  Tottenham Hotspur
# 673        EngPr  2241996.0  2017-02-04    17:30:00  Tottenham Hotspur
# 674        EngPr  2241996.0  2017-02-04    17:30:00  Tottenham Hotspur
# 675        EngPr  2241996.0  2017-02-04    17:30:00  Tottenham Hotspur
# 676        EngPr  2241996.0  2017-02-04    17:30:00  Tottenham Hotspur
# 677        EngPr  2241996.0  2017-02-04    17:30:00  Tottenham Hotspur
# 678        EngPr  2241996.0  2017-02-04    17:30:00  Tottenham Hotspur
# 679        EngPr  2241996.0  2017-02-04    17:30:00  Tottenham Hotspur
# 680        EngPr  2241996.0  2017-02-04    17:30:00  Tottenham Hotspur
# 681        EngPr  2241996.0  2017-02-04    17:30:00  Tottenham Hotspur
# 682        EngPr  2241996.0  2017-02-04    17:30:00  Tottenham Hotspur
# ...
