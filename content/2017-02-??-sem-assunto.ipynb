# %%
chances_files <- file.path('data', list.files('data', pattern='StrataData_Chances_.*.csv'))
chances <- lapply(chances_files, read.csv)

# excluding penalty kicks
#chances <- chances[chances$location_x != '-' && chances$location_y != '-']
#chances.location_x = pd.to_numeric(chances.location_x)
#chances.location_y = pd.to_numeric(chances.location_y)

#free_kicks = chances[chances.type.isin(['Direct Free-Kick', 'Direct free kick'])]
#free_kicks.outcome.replace('-', 'Goal', inplace=True)
#sns.FacetGrid(free_kicks, hue='outcome', size=12).map(plt.scatter, 'location_y', 'location_x').add_legend()
#plt.imshow(field, extent=[0, 420, -136, 136])
#plt.show()
#free_kicks.iloc[0]

# %%
chances
# Out:
# [[1]]
#        X competition  gsm_id kickoffDate kickoffTime       hometeam_team1
# 1    425       EngPr 2241994  2017-02-05    13:30:00      Manchester City
# 2    426       EngPr 2241994  2017-02-05    13:30:00      Manchester City
# 3    427       EngPr 2241994  2017-02-05    13:30:00      Manchester City
# 4    428       EngPr 2241994  2017-02-05    13:30:00      Manchester City
# 5    429       EngPr 2241994  2017-02-05    13:30:00      Manchester City
# 6    430       EngPr 2241994  2017-02-05    13:30:00      Manchester City
# 7    431       EngPr 2241994  2017-02-05    13:30:00      Manchester City
# 8    432       EngPr 2241994  2017-02-05    13:30:00      Manchester City
# 9    433       EngPr 2241994  2017-02-05    13:30:00      Manchester City
# 10   434       EngPr 2241994  2017-02-05    13:30:00      Manchester City
# 11   435       EngPr 2241994  2017-02-05    13:30:00      Manchester City
# 12   436       EngPr 2241994  2017-02-05    13:30:00      Manchester City
# ...
